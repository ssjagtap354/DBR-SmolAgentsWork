# %%
run_day = dbutils.jobs.taskValues.get("01_task_set_day","run_date",debugValue="2024-03-15")
print(run_day)

# %% [markdown]
# ### How notebokks pass values to each other ? or in a ntshell how pipeline is created in DBR
# - let say we want to return some values like value or date to downstream NB's then in first NB dbutils.jobs.taskvalues.set("var_name", actual_Value_to_pass)
# - in upstream NB use dbutils.jobs,taskvalues.get('tasknamethatwe createdin run', 'samevarname')
# - when we create widgets we dont have to manually pass the value , when we create task and add NB to it, in parameters we can get notebook.values.widgetname to assign value .

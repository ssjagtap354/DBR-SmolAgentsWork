# %%
list_of_gold_nb = [
    "/Workspace/Users/sac83775@gmail.com/8.Dim_customers_to_gold_processing",
    "/Workspace/Users/sac83775@gmail.com/9.Dim_Date_To_Gold_Processing",
    "/Workspace/Users/sac83775@gmail.com/10.Dim_Orders_to_Gold_processing"
]

for each_nb in list_of_gold_nb:
    print(f"Run started for {each_nb}")
    ret_code = dbutils.notebook.run(each_nb, 0)

    if ret_code == 'SUCCESS':
        print(f"Run ended for {each_nb}")
    else:
        raise Exception(f"Run failed for {each_nb}")

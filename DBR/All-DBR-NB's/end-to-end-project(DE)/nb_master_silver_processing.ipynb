# %% [markdown]
# ### This is master notebook for Silver processing
# - this will run all Silver NB's based on success of previous NB's

# %%
notebooks = [
    "/Workspace/Users/sac83775@gmail.com/2.Dim_orders_to_bronze_&_Silver_Processing",
    "/Workspace/Users/sac83775@gmail.com/3.Dim_brands_to_silver_processing",
    "/Workspace/Users/sac83775@gmail.com/4.Dim_category_to_silver_processing",
    "/Workspace/Users/sac83775@gmail.com/5.Dim_products_to_silver_processing",
    "/Workspace/Users/sac83775@gmail.com/6.Dim_customers_to_silver_processing",
    "/Workspace/Users/sac83775@gmail.com/7.Dim_date_to_silver_processing"
]

for nb in notebooks:
    print(f"Running {nb}")
    result = dbutils.notebook.run(nb, 0)

    if result != "SUCCESS":
        raise Exception(f"{nb} failed")

    print(f"{nb} completed")
